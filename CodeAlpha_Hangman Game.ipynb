# %%
import random

def hangman():
    # Predefined list of 5 words
    words = ["python", "flask", "machine", "learning", "project"]
    # Randomly select one word
    word = random.choice(words)
    
    # To keep track of guessed letters
    guessed_letters = []
    # Number of incorrect attempts allowed
    attempts = 6
    
    print("🎯 Welcome to Hangman!")
    print("Guess the word one letter at a time.")
    
    # Create a hidden version of the word using underscores
    display_word = ["_"] * len(word)
    
    # Game loop
    while attempts > 0 and "_" in display_word:
        print("\nWord:", " ".join(display_word))
        print(f"Incorrect guesses left: {attempts}")
        guess = input("Enter a letter: ").lower()
        
        # Validate input
        if len(guess) != 1 or not guess.isalpha():
            print("❌ Please enter a single alphabet letter.")
            continue
        if guess in guessed_letters:
            print("⚠️ You already guessed that letter.")
            continue
        
        guessed_letters.append(guess)
        
        # Check if the guessed letter is in the word
        if guess in word:
            print("✅ Correct guess!")
            for i in range(len(word)):
                if word[i] == guess:
                    display_word[i] = guess
        else:
            print("❌ Wrong guess!")
            attempts -= 1
    
    # End of game
    if "_" not in display_word:
        print("\n🎉 Congratulations! You guessed the word:", word)
    else:
        print("\n💀 Out of attempts! The word was:", word)

# Run the game
hangman()
# Out:
# 🎯 Welcome to Hangman!
# Guess the word one letter at a time.
#
# Word: _ _ _ _ _ _
# Incorrect guesses left: 6
# ❌ Wrong guess!
#
# Word: _ _ _ _ _ _
# Incorrect guesses left: 5
# ❌ Wrong guess!
#
# Word: _ _ _ _ _ _
# Incorrect guesses left: 4
# ❌ Wrong guess!
#
# Word: _ _ _ _ _ _
# Incorrect guesses left: 3
# ❌ Wrong guess!
#
# Word: _ _ _ _ _ _
# Incorrect guesses left: 2
# ✅ Correct guess!
#
# Word: _ y _ _ _ _
# Incorrect guesses left: 2
# ✅ Correct guess!
#
# Word: _ y _ _ _ n
# Incorrect guesses left: 2
# ⚠️ You already guessed that letter.
#
# Word: _ y _ _ _ n
# Incorrect guesses left: 2
# ❌ Wrong guess!
#
# Word: _ y _ _ _ n
# Incorrect guesses left: 1
# ⚠️ You already guessed that letter.
#
# Word: _ y _ _ _ n
# Incorrect guesses left: 1
# ✅ Correct guess!
#
# Word: p y _ _ _ n
# Incorrect guesses left: 1
# ✅ Correct guess!
#
# Word: p y t _ _ n
# Incorrect guesses left: 1
# ✅ Correct guess!
#
# Word: p y t h _ n
# Incorrect guesses left: 1
# ✅ Correct guess!
#
# 🎉 Congratulations! You guessed the word: python

# %%
import random

def hangman():
    # Predefined list of 5 words
    words = ["python", "flask", "machine", "learning", "project"]
    # Randomly select one word
    word = random.choice(words)
    
    # To keep track of guessed letters
    guessed_letters = []
    # Number of incorrect attempts allowed
    attempts = 6
    
    print("🎯 Welcome to Hangman!")
    print("Guess the word one letter at a time.")
    
    # Create a hidden version of the word using underscores
    display_word = ["_"] * len(word)
    
    # Game loop
    while attempts > 0 and "_" in display_word:
        print("\nWord:", " ".join(display_word))
        print(f"Incorrect guesses left: {attempts}")
        print("Guessed letters:", " ".join(sorted(guessed_letters)) if guessed_letters else "None")
        
        guess = input("Enter a letter: ").lower()
        
        # Validate input
        if len(guess) != 1 or not guess.isalpha():
            print("❌ Please enter a single alphabet letter.")
            continue
        if guess in guessed_letters:
            print("⚠️ You already guessed that letter.")
            continue
        
        guessed_letters.append(guess)
        
        # Check if the guessed letter is in the word
        if guess in word:
            print("✅ Correct guess!")
            for i in range(len(word)):
                if word[i] == guess:
                    display_word[i] = guess
        else:
            print("❌ Wrong guess!")
            attempts -= 1
    
    # End of game
    if "_" not in display_word:
        print("\n🎉 Congratulations! You guessed the word:", word)
    else:
        print("\n💀 Out of attempts! The word was:", word)

# Run the game
hangman()
# Out:
# 🎯 Welcome to Hangman!
# Guess the word one letter at a time.
#
# Word: _ _ _ _ _ _ _ _
# Incorrect guesses left: 6
# Guessed letters: None
# ✅ Correct guess!
#
# Word: _ _ a _ _ _ _ _
# Incorrect guesses left: 6
# Guessed letters: a
# ⚠️ You already guessed that letter.
#
# Word: _ _ a _ _ _ _ _
# Incorrect guesses left: 6
# Guessed letters: a
# ✅ Correct guess!
#
# Word: l _ a _ _ _ _ _
# Incorrect guesses left: 6
# Guessed letters: a l
# ⚠️ You already guessed that letter.
#
# Word: l _ a _ _ _ _ _
# Incorrect guesses left: 6
# Guessed letters: a l
# ✅ Correct guess!
#
# Word: l e a _ _ _ _ _
# Incorrect guesses left: 6
# Guessed letters: a e l
# ❌ Wrong guess!
#
# Word: l e a _ _ _ _ _
# Incorrect guesses left: 5
# Guessed letters: a e l m
# ⚠️ You already guessed that letter.
#
# Word: l e a _ _ _ _ _
# Incorrect guesses left: 5
# Guessed letters: a e l m
# ✅ Correct guess!
#
# Word: l e a _ n _ n _
# Incorrect guesses left: 5
# Guessed letters: a e l m n
# ✅ Correct guess!
#
# Word: l e a r n _ n _
# Incorrect guesses left: 5
# Guessed letters: a e l m n r
# ✅ Correct guess!
#
# Word: l e a r n i n _
# Incorrect guesses left: 5
# Guessed letters: a e i l m n r
# ✅ Correct guess!
#
# 🎉 Congratulations! You guessed the word: learning
